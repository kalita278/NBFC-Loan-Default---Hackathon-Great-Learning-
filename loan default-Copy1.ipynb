# %%
#Importing the library
import numpy as np
import pandas as pd
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,classification_report

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.metrics import recall_score, precision_score, f1_score
from sklearn.preprocessing import StandardScaler

#import imblearn
#from imblearn.over_sampling import SMOTE
from scipy.stats import chi2_contingency


import warnings
warnings.filterwarnings('ignore')

# %%
#loading the training and testing data
df_train = pd.read_csv('E:/Data Science/NBFC Loan Default/Train_set_(1)_(1).csv')
df_test = pd.read_csv('E:/Data Science/NBFC Loan Default/Test_set_(1)_(2).csv')

# %% [markdown]
# # Data Exploration

# %%
#Checking the first 5 rows
df_train.head()
# Out:
#          ID  loan_amnt loan_term  interest_rate loan_grade loan_subgrade  \
# 0  72199369       9000   3 years           9.17          B            B2
# 1  14257956      18000   3 years          13.65          C            C1
# 2  66216451      16000   3 years           7.26          A            A4
# 3  46974169      25000   3 years          13.99          C            C4
# 4  46725961      17000   3 years           6.39          A            A2
#
#   job_experience home_ownership  annual_income income_verification_status  \
# 0       <5 Years            OWN        85000.0               Not Verified
# 1       <5 Years            OWN        64000.0                   Verified
# 2       <5 Years       MORTGAGE       150000.0            Source Verified
# 3            NaN       MORTGAGE        59800.0                   Verified
# 4      10+ years       MORTGAGE        72000.0            Source Verified
#
#    ... delinq_2yrs public_records  revolving_balance  total_acc  \
# 0  ...         0.0            0.0              39519       20.0
# 1  ...         0.0            1.0               9783       24.0
# 2  ...         2.0            0.0              13641       27.0
# 3  ...         0.0            0.0              35020       35.0
# 4  ...         0.0            0.0              23990       26.0
#
#    interest_receive  application_type  last_week_pay  total_current_balance  \
# 0             59.60        INDIVIDUAL            4.0                95493.0
# 1           3348.25        INDIVIDUAL           95.0               185433.0
# 2            276.69        INDIVIDUAL           13.0               180519.0
# 3           1106.72        INDIVIDUAL           17.0               183208.0
# 4            725.29        INDIVIDUAL           39.0                23990.0
#
#   total_revolving_limit  default
# 0               84100.0        0
# 1               13500.0        0
# 2               19300.0        0
# 3               55400.0        0
# 4               81300.0        0
#
# [5 rows x 23 columns]

# %%
#Checking the shape
df_train.shape
# Out:
# (93174, 23)

# %%
#Checking the info
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93174 entries, 0 to 93173
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          93174 non-null  int64
#  1   loan_amnt                   93174 non-null  int64
#  2   loan_term                   93174 non-null  object
#  3   interest_rate               93174 non-null  float64
#  4   loan_grade                  93174 non-null  object
#  5   loan_subgrade               93174 non-null  object
#  6   job_experience              88472 non-null  object
#  7   home_ownership              93174 non-null  object
#  8   annual_income               93173 non-null  float64
#  9   income_verification_status  93174 non-null  object
#  10  loan_purpose                93174 non-null  object
#  11  state_code                  93174 non-null  object
#  12  debt_to_income              93174 non-null  float64
#  13  delinq_2yrs                 93172 non-null  float64
#  14  public_records              93172 non-null  float64
#  15  revolving_balance           93174 non-null  int64
#  16  total_acc                   93172 non-null  float64
#  17  interest_receive            93174 non-null  float64
#  18  application_type            93174 non-null  object
#  19  last_week_pay               91250 non-null  float64
#  20  total_current_balance       85788 non-null  float64
#  21  total_revolving_limit       85788 non-null  float64
#  22  default                     93174 non-null  int64
# dtypes: float64(10), int64(4), object(9)
# memory usage: 16.3+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39933 entries, 0 to 39932
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          39933 non-null  int64
#  1   loan_amnt                   39933 non-null  int64
#  2   loan_term                   39933 non-null  object
#  3   interest_rate               39933 non-null  float64
#  4   loan_grade                  39933 non-null  object
#  5   loan_subgrade               39933 non-null  object
#  6   job_experience              37844 non-null  object
#  7   home_ownership              39933 non-null  object
#  8   annual_income               39933 non-null  float64
#  9   income_verification_status  39933 non-null  object
#  10  loan_purpose                39933 non-null  object
#  11  state_code                  39933 non-null  object
#  12  debt_to_income              39933 non-null  float64
#  13  delinq_2yrs                 39932 non-null  float64
#  14  public_records              39932 non-null  float64
#  15  revolving_balance           39933 non-null  int64
#  16  total_acc                   39932 non-null  float64
#  17  interest_receive            39933 non-null  float64
#  18  application_type            39933 non-null  object
#  19  last_week_pay               39127 non-null  float64
#  20  total_current_balance       36703 non-null  float64
#  21  total_revolving_limit       36703 non-null  float64
# dtypes: float64(10), int64(3), object(9)
# memory usage: 6.7+ MB

# %% [markdown]
# # Data Cleaning

# %%
#Checking duplicate values
df_train.duplicated().sum()
# Out:
# 0

# %%
#Checking missing values
df_train.isnull().sum()
# Out:
# ID                               0
# loan_amnt                        0
# loan_term                        0
# interest_rate                    0
# loan_grade                       0
# loan_subgrade                    0
# job_experience                4702
# home_ownership                   0
# annual_income                    1
# income_verification_status       0
# loan_purpose                     0
# state_code                       0
# debt_to_income                   0
# delinq_2yrs                      2
# public_records                   2
# revolving_balance                0
# total_acc                        2
# interest_receive                 0
# application_type                 0
# last_week_pay                 1924
# total_current_balance         7386
# total_revolving_limit         7386
# default                          0
# dtype: int64

# %%
#dropping the ID column
df_train = df_train.drop(['ID','state_code','loan_grade'],axis=1)

# %%
#Encode categorical variable
cat_col = ['loan_term','loan_subgrade','job_experience','home_ownership','income_verification_status','loan_purpose','application_type']
df_train['loan_term'] = df_train.loan_term.map({'3 years':0,'5 years':1})
df_train['loan_subgrade'] = df_train.loan_subgrade.map({'A1':0,'A2':1,'A3':2,'A4':3,'A5':4,'B1':5,'B2':6,'B3':7,'B4':8,'B5':9,'C1':10,'C2':11,'C3':12,'C4':13,'C5':14,
                                                    'D1':15,'D2':16,'D3':17,'D4':18,'D5':19,'E1':20,'E2':21,'E3':22,'E4':23,'E5':24,'F1':25,'F2':26,'F3':27,'F4':28,'F5':29,
                                                'G1':30,'G2':31,'G3':32,'G4':33,'G5':34})
df_train['job_experience'] =df_train.job_experience.map({'<5 Years':0,'6-10 years':1,'10+ years':2})
df_train['home_ownership'] = df_train.home_ownership.map({'MORTGAGE':0,'RENT':1,'OWN':2,'OTHER':3,'NONE':4})
df_train['income_verification_status'] = df_train.income_verification_status.map({'Source Verified':0,'Verified':1,'Not Verified':2})
df_train['loan_purpose'] = df_train.loan_purpose.map({'debt_consolidation':0,'credit_card':1,'other':2,'home_improvement':3})
df_train['application_type'] = df_train.application_type.map({'INDIVIDUAL':0,'JOINT':1})

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=7)
df_train[['annual_income','delinq_2yrs','public_records','total_acc','last_week_pay','total_current_balance']] = imputer.fit_transform(X=df_train[['annual_income','delinq_2yrs','public_records','total_acc','last_week_pay','total_current_balance']])

# %% [markdown]
# # EDA

# %%
#Dropping total_revolving_limit
df_train = df_train.drop('total_revolving_limit',axis=1)
df_test = df_test.drop('total_revolving_limit',axis=1)

# %%
#Chi Square test for all categorical variable
cat_col = ['loan_term','loan_subgrade','job_experience','home_ownership','income_verification_status','loan_purpose',
           'application_type']
for col in cat_col:
    cross_tab = pd.crosstab(df_train[col],df_train['default'])
    chi2, p, dof, expected = chi2_contingency(cross_tab)
    
    if p < 0.05:
        print('For',col,': p =',p,',Since p < 0.05, There is a relationship between',col,'and default.')
    else:
        print('For',col,': p =',p,',Since p > 0.05, There is no relationship between',col,'and default.')
# Out:
# For loan_term : p = 0.0 ,Since p < 0.05, There is a relationship between loan_term and default.
# For loan_subgrade : p = 7.20260619090703e-100 ,Since p < 0.05, There is a relationship between loan_subgrade and default.
# For job_experience : p = 3.139835375705397e-23 ,Since p < 0.05, There is a relationship between job_experience and default.
# For home_ownership : p = 1.8474415714935548e-19 ,Since p < 0.05, There is a relationship between home_ownership and default.
# For income_verification_status : p = 5.615080262506217e-183 ,Since p < 0.05, There is a relationship between income_verification_status and default.
# For loan_purpose : p = 2.1886850683537214e-89 ,Since p < 0.05, There is a relationship between loan_purpose and default.
# For application_type : p = 5.803574384959491e-05 ,Since p < 0.05, There is a relationship between application_type and default.

# %%
#Calculating the number of outlier in each feature of the dataset
des = df_train.describe()
for col in des.columns:
    q1 = des.loc['25%',col]
    q3 = des.loc['75%',col]
    iqr = q3-q1
    upper_fence = q3 + 1.5*iqr
    lower_fence = q1 -1.5*iqr
    print("Number of outlier in", col ,"feature is", 
          len(df_train[col][(df_train[col]>upper_fence) | (df_train[col]<lower_fence)]))
# Out:
# Number of outlier in loan_amnt feature is 0
# Number of outlier in loan_term feature is 0
# Number of outlier in interest_rate feature is 610
# Number of outlier in loan_subgrade feature is 785
# Number of outlier in job_experience feature is 0
# Number of outlier in home_ownership feature is 26
# Number of outlier in annual_income feature is 4201
# Number of outlier in income_verification_status feature is 0
# Number of outlier in loan_purpose feature is 5391
# Number of outlier in debt_to_income feature is 9
# Number of outlier in delinq_2yrs feature is 17858
# Number of outlier in public_records feature is 14238
# Number of outlier in revolving_balance feature is 5044
# Number of outlier in total_acc feature is 1950
# Number of outlier in interest_receive feature is 6766
# Number of outlier in application_type feature is 56
# Number of outlier in last_week_pay feature is 618
# Number of outlier in total_current_balance feature is 3267
# Number of outlier in default feature is 22129

# %%
#Imputing outliers 
des1 = df_train.describe()
columns=['interest_rate','annual_income','debt_to_income','delinq_2yrs','public_records','revolving_balance','total_acc','interest_receive',
         'last_week_pay','total_current_balance']
for col in columns:
    q1 = des1.loc['25%',col]
    q3 = des1.loc['75%',col]
    iqr = q3-q1
    upper_fence = q3 + 1.5*iqr
    lower_fence = q1 -1.5*iqr
    df_include = df_train.loc[(df_train[col] >= lower_fence) & (df_train[col] <= upper_fence)]
    mean = df_include[col].mean()
    df_train[col]=np.where(df_train[col]>upper_fence,upper_fence,df_train[col])
    df_train[col]=np.where(df_train[col] < lower_fence, lower_fence,df_train[col])
    print("Number of outlier after imputing outlier with mean in", col ,"feature is", 
          len(df_train[col][(df_train[col]>upper_fence) | (df_train[col]<lower_fence)]))
# Out:
# Number of outlier after imputing outlier with mean in interest_rate feature is 0
# Number of outlier after imputing outlier with mean in annual_income feature is 0
# Number of outlier after imputing outlier with mean in debt_to_income feature is 0
# Number of outlier after imputing outlier with mean in delinq_2yrs feature is 0
# Number of outlier after imputing outlier with mean in public_records feature is 0
# Number of outlier after imputing outlier with mean in revolving_balance feature is 0
# Number of outlier after imputing outlier with mean in total_acc feature is 0
# Number of outlier after imputing outlier with mean in interest_receive feature is 0
# Number of outlier after imputing outlier with mean in last_week_pay feature is 0
# Number of outlier after imputing outlier with mean in total_current_balance feature is 0

# %% [markdown]
# # Data Preparation

# %%
x=df_train.drop('default',axis=1)
y=df_train['default'].values

# %%
x = pd.get_dummies(data=x,columns=cat_col)

# %%
sc = StandardScaler()
x = sc.fit_transform(x)

# %% [markdown]
# # Testing Data Preparation

# %%
#Encode categorical variable
cat_col = ['loan_term','loan_subgrade','job_experience','home_ownership','income_verification_status','loan_purpose','application_type']
df_test['loan_term'] = df_test.loan_term.map({'3 years':0,'5 years':1})
df_test['loan_subgrade'] = df_test.loan_subgrade.map({'A1':0,'A2':1,'A3':2,'A4':3,'A5':4,'B1':5,'B2':6,'B3':7,'B4':8,'B5':9,'C1':10,'C2':11,'C3':12,'C4':13,'C5':14,
                                                    'D1':15,'D2':16,'D3':17,'D4':18,'D5':19,'E1':20,'E2':21,'E3':22,'E4':23,'E5':24,'F1':25,'F2':26,'F3':27,'F4':28,'F5':29,
                                                'G1':30,'G2':31,'G3':32,'G4':33,'G5':34})
df_test['job_experience'] = df_test.job_experience.map({'<5 Years':0,'6-10 years':1,'10+ years':2})
df_test['home_ownership'] = df_test.home_ownership.map({'MORTGAGE':0,'RENT':1,'OWN':2,'OTHER':3,'NONE':4})
df_test['income_verification_status'] = df_test.income_verification_status.map({'Source Verified':0,'Verified':1,'Not Verified':2})
df_test['loan_purpose'] = df_test.loan_purpose.map({'debt_consolidation':0,'credit_card':1,'other':2,'home_improvement':3})
df_test['application_type'] = df_test.application_type.map({'INDIVIDUAL':0,'JOINT':1})

# %%
df_test[['annual_income','delinq_2yrs','public_records','total_acc','last_week_pay','total_current_balance']] = imputer.transform(X=df_test[['annual_income','delinq_2yrs','public_records','total_acc','last_week_pay','total_current_balance']])

# %%
x_sample = df_test.drop(['ID','state_code','loan_grade'],axis=1)

# %%
x_sample = pd.get_dummies(data=x_sample, columns=cat_col)

# %%
x_sample = sc.transform(x_sample)

# %% [markdown]
# # Training Neural Networks

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=512,activation = 'relu',kernel_initializer='he_uniform'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(units=264,activation = 'relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.35))
model.add(tf.keras.layers.Dense(units=128,activation = 'relu'))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(units=64,activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(units=1,activation = 'sigmoid'))

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['Accuracy','Precision','Recall'])

# %%
model.fit(x,y,batch_size=224,epochs=150)
# Out:
# Epoch 1/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.5409 - accuracy: 0.0000e+00 - precision: 0.4506 - recall: 0.1873
# Epoch 2/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.4986 - accuracy: 0.0000e+00 - precision: 0.6102 - recall: 0.1761
# Epoch 3/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.4855 - accuracy: 0.0000e+00 - precision: 0.6553 - recall: 0.1809
# Epoch 4/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.4732 - accuracy: 0.0000e+00 - precision: 0.6625 - recall: 0.2153
# Epoch 5/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.4574 - accuracy: 0.0000e+00 - precision: 0.6703 - recall: 0.2862
# Epoch 6/150
# 416/416 [==============================] - 9s 21ms/step - loss: 0.4358 - accuracy: 0.0000e+00 - precision: 0.6887 - recall: 0.3624
# Epoch 7/150
# 416/416 [==============================] - 9s 20ms/step - loss: 0.4227 - accuracy: 0.0000e+00 - precision: 0.6932 - recall: 0.4005: 1s - loss: 0.4230 - accuracy: 0.0000e+00 - precision: 0.6910 - recall: 0 - ETA: 1s - loss: 0.4230 - accuracy: 0.0000e+00 - precision: 0.6922 - r - ETA: 0s - loss: 0.4227 - accuracy: 0.0000e+00 - precision: 0.6910 - recall: 0 - ETA: 0s - loss: 0.4225 - accuracy: 0.0000e+00 - precision: 0.6923 - recall:
# Epoch 8/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.4104 - accuracy: 0.0000e+00 - precision: 0.7094 - recall: 0.4383: 3s - loss: 0.4105 - accuracy: 0.0000e+00 - precision: 0.7095 - recall - ETA: 2s - loss: 0.4095 - accuracy: 0.0000e+00 - precision: 0.7109 - recal - ETA: 2s - loss: 0.4104 - accuracy: 0.0000
# Epoch 9/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.4018 - accuracy: 0.0000e+00 - precision: 0.7164 - recall: 0.4650: 3s - loss: 0.4038 - accuracy: 0.0000e+00 - precision: 0.7161 - recall: 0.460 - ETA: 3s - loss: 0.4
# Epoch 10/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3950 - accuracy: 0.0000e+00 - precision: 0.7157 - recall: 0.4866
# Epoch 11/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3890 - accuracy: 0.0000e+00 - precision: 0.7254 - recall: 0.5015: 6s - loss: 0.3838 - accuracy: 0.0000e+00 - pr
# Epoch 12/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3830 - accuracy: 0.0000e+00 - precision: 0.7293 - recall: 0.5132: 3s - loss: 0.3844
# Epoch 13/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3787 - accuracy: 0.0000e+00 - precision: 0.7299 - recall: 0.5248:
# Epoch 14/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3755 - accuracy: 0.0000e+00 - precision: 0.7329 - recall: 0.5338
# Epoch 15/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3719 - accuracy: 0.0000e+00 - precision: 0.7362 - recall: 0.5375
# Epoch 16/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3696 - accuracy: 0.0000e+00 - precision: 0.7403 - recall: 0.5471
# Epoch 17/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3679 - accuracy: 0.0000e+00 - precision: 0.7397 - recall: 0.5547: 7s - loss: 0.3684 - accuracy
# Epoch 18/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3649 - accuracy: 0.0000e+00 - precision: 0.7394 - recall: 0.5574
# Epoch 19/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3631 - accuracy: 0.0000e+00 - precision: 0.7410 - recall: 0.5594
# Epoch 20/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3610 - accuracy: 0.0000e+00 - precision: 0.7472 - recall: 0.5618
# Epoch 21/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3606 - accuracy: 0.0000e+00 - precision: 0.7480 - recall: 0.5655
# Epoch 22/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3589 - accuracy: 0.0000e+00 - precision: 0.7477 - recall: 0.5653
# Epoch 23/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3567 - accuracy: 0.0000e+00 - precision: 0.7483 - recall: 0.5705
# Epoch 24/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3549 - accuracy: 0.0000e+00 - precision: 0.7498 - recall: 0.5778: 6s - loss: 0.3541 - accuracy: 0.0000e+00 - precis
# Epoch 25/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3540 - accuracy: 0.0000e+00 - precision: 0.7523 - recall: 0.5784
# Epoch 26/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3531 - accuracy: 0.0000e+00 - precision: 0.7533 - recall: 0.5784
# Epoch 27/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3521 - accuracy: 0.0000e+00 - precision: 0.7517 - recall: 0.5839
# Epoch 28/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3502 - accuracy: 0.0000e+00 - precision: 0.7533 - recall: 0.5881
# Epoch 29/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3494 - accuracy: 0.0000e+00 - precision: 0.7541 - recall: 0.5845
# Epoch 30/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3482 - accuracy: 0.0000e+00 - precision: 0.7573 - recall: 0.5910: 1s - loss: 0.3470 - accuracy: 0.0000e+00 - precision:
# Epoch 31/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3470 - accuracy: 0.0000e+00 - precision: 0.7606 - recall: 0.5905: 5s - loss: 0.3443 - accuracy: 0.0000e+00 - precision: 0.7628 - recal - ET
# Epoch 32/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3485 - accuracy: 0.0000e+00 - precision: 0.7546 - recall: 0.5880: 3s - loss: 0.3450 - ac
# Epoch 33/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3465 - accuracy: 0.0000e+00 - precision: 0.7571 - recall: 0.5918
# Epoch 34/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3457 - accuracy: 0.0000e+00 - precision: 0.7565 - recall: 0.5918: 7s - loss: 0.3446 - accuracy - ETA: 3s - loss: 0.34
# Epoch 35/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3443 - accuracy: 0.0000e+00 - precision: 0.7596 - recall: 0.5928
# Epoch 36/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3428 - accuracy: 0.0000e+00 - precision: 0.7623 - recall: 0.5967
# Epoch 37/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3435 - accuracy: 0.0000e+00 - precision: 0.7601 - recall: 0.5950
# Epoch 38/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3423 - accuracy: 0.0000e+00 - precision: 0.7651 - recall: 0.5969
# Epoch 39/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3408 - accuracy: 0.0000e+00 - precision: 0.7615 - recall: 0.6022
# Epoch 40/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3402 - accuracy: 0.0000e+00 - precision: 0.7631 - recall: 0.5967: 2s - loss: 0.3389 - accuracy: 0.000
# Epoch 41/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3405 - accuracy: 0.0000e+00 - precision: 0.7617 - recall: 0.5985: 7s - loss: 0.3400 - accu - ETA: 3s - loss: 0.3401 - accuracy: 0.0000e+00 - precision: 0.7 - ETA: 2s - loss: 0.3404 - accuracy: 0.00
# Epoch 42/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3385 - accuracy: 0.0000e+00 - precision: 0.7672 - recall: 0.5985: 0s - loss: 0.3377 - accuracy: 0.0000e+00 - precision: 0.7669 - recall: 0. - ETA: 0s - loss: 0.3379 - accuracy: 0.0000e+00 - precision: 0.7675 - recall: 0.5
# Epoch 43/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3385 - accuracy: 0.0000e+00 - precision: 0.7601 - recall: 0.6017: 3s - loss:
# Epoch 44/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3380 - accuracy: 0.0000e+00 - precision: 0.7626 - recall: 0.6022
# Epoch 45/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3370 - accuracy: 0.0000e+00 - precision: 0.7660 - recall: 0.6031: 1s - loss: 0.3376 - accuracy: 0.0000e+00 - precision:
# Epoch 46/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3365 - accuracy: 0.0000e+00 - precision: 0.7694 - recall: 0.5976A: 1s - loss: 0.3362 - accuracy: 0.0000e+00 - pre
# Epoch 47/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3367 - accuracy: 0.0000e+00 - precision: 0.7684 - recall: 0.5988
# Epoch 48/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3353 - accuracy: 0.0000e+00 - precision: 0.7664 - recall: 0.6054
# Epoch 49/150
# 416/416 [==============================] - 9s 22ms/step - loss: 0.3355 - accuracy: 0.0000e+00 - precision: 0.7684 - recall: 0.6026: 2s - loss: 0.3334 - accuracy
# Epoch 50/150
# 416/416 [==============================] - 11s 26ms/step - loss: 0.3346 - accuracy: 0.0000e+00 - precision: 0.7676 - recall: 0.6082 2s - loss: 0.3343 - accuracy: 0. - ETA: 0s - loss: 0.3345 - accuracy: 0.0000e+00 - precision: 0.7676 - recall: 0.6
# Epoch 51/150
# 416/416 [==============================] - 10s 23ms/step - loss: 0.3342 - accuracy: 0.0000e+00 - precision: 0.7661 - recall: 0.6059
# Epoch 52/150
# 416/416 [==============================] - 9s 23ms/step - loss: 0.3330 - accuracy: 0.0000e+00 - precision: 0.7690 - recall: 0.6076: 4s -  - ETA: 0s - loss: 0.3332 - accuracy: 0.0000e+00 - precision: 0.7691 - recall:
# Epoch 53/150
# 416/416 [==============================] - 9s 23ms/step - loss: 0.3334 - accuracy: 0.0000e+00 - precision: 0.7666 - recall: 0.6075
# Epoch 54/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3324 - accuracy: 0.0000e+00 - precision: 0.7680 - recall: 0.6078
# Epoch 55/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3317 - accuracy: 0.0000e+00 - precision: 0.7699 - recall: 0.6079
# Epoch 56/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3308 - accuracy: 0.0000e+00 - precision: 0.7718 - recall: 0.6119: 5s - loss: 0.3253 - accuracy: 0 - ETA: 2s - loss: 0.3303 - accuracy: 0.0000
# Epoch 57/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3325 - accuracy: 0.0000e+00 - precision: 0.7676 - recall: 0.6093: 4s - loss: 0.3322 - accuracy: 0.0000e+00 - ETA: 2s - loss: 0.3331 - accuracy: 0.0000e+00
# Epoch 58/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3314 - accuracy: 0.0000e+00 - precision: 0.7694 - recall: 0.6101
# Epoch 59/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3301 - accuracy: 0.0000e+00 - precision: 0.7720 - recall: 0.6105A: 2s - loss: 0.3287 - accuracy: 0.0000e+00 -
# Epoch 60/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3302 - accuracy: 0.0000e+00 - precision: 0.7719 - recall: 0.6090
# Epoch 61/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3306 - accuracy: 0.0000e+00 - precision: 0.7739 - recall: 0.6106: 2s - loss: 0.3292 - accuracy: 0
# Epoch 62/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3292 - accuracy: 0.0000e+00 - precision: 0.7696 - recall: 0.6139: 6s - loss: 0.3329 - accuracy: 0.0000e+00 - pre - ETA: 5s - loss: 0.3313 - accuracy: 0.0000e+00 - precision: 0.7749 - recall: 0. - E
# Epoch 63/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3286 - accuracy: 0.0000e+00 - precision: 0.7717 - recall: 0.6116: 1s - loss: 0.3280 - accuracy: 0.0000e+00 - precision: 0.7708
# Epoch 64/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3277 - accuracy: 0.0000e+00 - precision: 0.7746 - recall: 0.6107: 6s - loss: 0.3224 - accuracy: 0.0000e+00 - precision:
# Epoch 65/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3283 - accuracy: 0.0000e+00 - precision: 0.7721 - recall: 0.6146
# Epoch 66/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3268 - accuracy: 0.0000e+00 - precision: 0.7720 - recall: 0.6130: 0s - loss: 0.3266 - accuracy: 0.0000e+00 - precision: 0.7711 - re
# Epoch 67/150
# 416/416 [==============================] - 9s 21ms/step - loss: 0.3271 - accuracy: 0.0000e+00 - precision: 0.7738 - recall: 0.6152
# Epoch 68/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3259 - accuracy: 0.0000e+00 - precision: 0.7709 - recall: 0.6204: 4s - loss: 0.3232 - accuracy: 0.0000e+00 - precision: 0 - ETA: 3s - loss: 0.3252 -
# Epoch 69/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3256 - accuracy: 0.0000e+00 - precision: 0.7721 - recall: 0.6193
# Epoch 70/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3259 - accuracy: 0.0000e+00 - precision: 0.7746 - recall: 0.6144: 6s - loss: 0.3279 - accuracy: 0.0000e+00 - prec
# Epoch 71/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3256 - accuracy: 0.0000e+00 - precision: 0.7715 - recall: 0.6209: 0s - loss: 0.3250 - accuracy: 0.0000e+00 - precision: 0.7723 - recal
# Epoch 72/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3236 - accuracy: 0.0000e+00 - precision: 0.7752 - recall: 0.6211: 2s - loss: 0.3240 - accuracy: 0.0000e+00 - pr - ETA: 0s - loss: 0.3235 - accuracy: 0.0000e+00 - precision: 0.7750 - re
# Epoch 73/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3260 - accuracy: 0.0000e+00 - precision: 0.7714 - recall: 0.6178
# Epoch 74/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3244 - accuracy: 0.0000e+00 - precision: 0.7750 - recall: 0.6206: 6s - loss: 0.3256 - accuracy: 0.0000e+0
# Epoch 75/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3250 - accuracy: 0.0000e+00 - precision: 0.7740 - recall: 0.6178
# Epoch 76/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3236 - accuracy: 0.0000e+00 - precision: 0.7786 - recall: 0.6168: 4s - loss: 0.3188 - accuracy: 0.0000e+00 - precision: 0 - ETA: 3s - loss: 0.3215 - accur
# Epoch 77/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3224 - accuracy: 0.0000e+00 - precision: 0.7743 - recall: 0.6214: 6s - loss: - ETA: 2s - loss: 0.3205 - accuracy: 0.0000e+00
# Epoch 78/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3234 - accuracy: 0.0000e+00 - precision: 0.7746 - recall: 0.6226: 4s
# Epoch 79/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3231 - accuracy: 0.0000e+00 - precision: 0.7763 - recall: 0.6187: 6s - loss: 0.3285 - accuracy: 0.0000e+00 - pr - ETA: 4s
# Epoch 80/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3231 - accuracy: 0.0000e+00 - precision: 0.7751 - recall: 0.6228: 3s - loss: 0.32
# Epoch 81/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3217 - accuracy: 0.0000e+00 - precision: 0.7777 - recall: 0.6189: 3s - loss: 0.3198 - accuracy: 0.0000e+00 - pr - ETA: 1s - loss: 0.3223 - accuracy: 0.0000e+00 - precision:
# Epoch 82/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3219 - accuracy: 0.0000e+00 - precision: 0.7779 - recall: 0.6239
# Epoch 83/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3196 - accuracy: 0.0000e+00 - precision: 0.7744 - recall: 0.6293
# Epoch 84/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3211 - accuracy: 0.0000e+00 - precision: 0.7733 - recall: 0.6214: 4s - loss: 0.3199 - ETA: 1s - loss: 0.3209 - accuracy: 0.0000e+00 - precision: 0.7
# Epoch 85/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3205 - accuracy: 0.0000e+00 - precision: 0.7768 - recall: 0.6249: 5s - loss: 0.3209 - accuracy: 0.0000e+00 - precision: 0.7 - ETA: 3s - loss: 0
# Epoch 86/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3215 - accuracy: 0.0000e+00 - precision: 0.7738 - recall: 0.6215: 1s - loss: 0.3223 - accuracy: 0.0000e+00 - preci
# Epoch 87/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3191 - accuracy: 0.0000e+00 - precision: 0.7775 - recall: 0.6273: 0s - loss: 0.3191 - accuracy: 0.0000e+00 - precision: 0.7787 -
# Epoch 88/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3200 - accuracy: 0.0000e+00 - precision: 0.7772 - recall: 0.6212: 0s - loss: 0.3200 - accuracy: 0.0000e+00 - precision: 0.7773 - recall
# Epoch 89/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3192 - accuracy: 0.0000e+00 - precision: 0.7757 - recall: 0.6284: 2s - loss: 0.3169 - accuracy: 0.0000e+00 - precision: 0.7786 - recall: 0.632 - ETA: 2s - loss: 0.3168 - accuracy: 0.0000
# Epoch 90/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3195 - accuracy: 0.0000e+00 - precision: 0.7786 - recall: 0.6268: 2s - loss: 0.3189 - accuracy: 0.00
# Epoch 91/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3193 - accuracy: 0.0000e+00 - precision: 0.7796 - recall: 0.6241: 0s - loss: 0.3193 - accuracy: 0.0000e+00 - precision: 0.7783 - rec
# Epoch 92/150
# 416/416 [==============================] - 9s 21ms/step - loss: 0.3196 - accuracy: 0.0000e+00 - precision: 0.7773 - recall: 0.6265: 5s - loss: 0.3227 - accuracy: 0.0000e+00 - precision: 0.7738 - recal - ETA: 5s - loss: 0.3242 - accuracy: 0.0000e+00 - precisi - ETA: 3s - loss: 0
# Epoch 93/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3188 - accuracy: 0.0000e+00 - precision: 0.7783 - recall: 0.6240
# Epoch 94/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3189 - accuracy: 0.0000e+00 - precision: 0.7776 - recall: 0.6277
# Epoch 95/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3186 - accuracy: 0.0000e+00 - precision: 0.7782 - recall: 0.6244
# Epoch 96/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3188 - accuracy: 0.0000e+00 - precision: 0.7782 - recall: 0.6279: 0s - loss: 0.3182 - accuracy: 0.0000e+00 - precision: 0.7776 -
# Epoch 97/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3180 - accuracy: 0.0000e+00 - precision: 0.7777 - recall: 0.6280: 5s - loss: 0.3126 - accuracy: 0.0000e+00 - precision: 0.7788 - recall - ETA: 4s - loss: 0.3134 - acc - ETA: 1s - loss: 0.3163 - accuracy: 0.0000e+00 - precision: 0.7791 - recall: - ETA: 1s - loss: 0.3171 - accuracy: 0.0000e+00 - precision: 0.
# Epoch 98/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3166 - accuracy: 0.0000e+00 - precision: 0.7799 - recall: 0.6284: 1s - loss: 0.3169 - accuracy: 0.0000e+00 - pre
# Epoch 99/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3181 - accuracy: 0.0000e+00 - precision: 0.7777 - recall: 0.6267
# Epoch 100/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3179 - accuracy: 0.0000e+00 - precision: 0.7763 - recall: 0.6295: 7s - loss: 0.3186 - accuracy: 0.0000e+00 - precisio - E - ETA: 0s - loss: 0.3172 - accuracy: 0.0000e+00 - precision: 0.7782 - reca
# Epoch 101/150
# 416/416 [==============================] - 9s 21ms/step - loss: 0.3179 - accuracy: 0.0000e+00 - precision: 0.7790 - recall: 0.6286: 3s - loss: 0.3131 - accuracy: 0.0000e+00 - precision: 0.7814 - re - ETA: 3s - loss: 0.3146 - acc
# Epoch 102/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3180 - accuracy: 0.0000e+00 - precision: 0.7779 - recall: 0.6334
# Epoch 103/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3161 - accuracy: 0.0000e+00 - precision: 0.7792 - recall: 0.6310
# Epoch 104/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3160 - accuracy: 0.0000e+00 - precision: 0.7796 - recall: 0.6279
# Epoch 105/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3157 - accuracy: 0.0000e+00 - precision: 0.7830 - recall: 0.6317
# Epoch 106/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3158 - accuracy: 0.0000e+00 - precision: 0.7774 - recall: 0.6315
# Epoch 107/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3150 - accuracy: 0.0000e+00 - precision: 0.7806 - recall: 0.6306
# Epoch 108/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3152 - accuracy: 0.0000e+00 - precision: 0.7772 - recall: 0.6307
# Epoch 109/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3164 - accuracy: 0.0000e+00 - precision: 0.7814 - recall: 0.6285: 4s - loss
# Epoch 110/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3139 - accuracy: 0.0000e+00 - precision: 0.7780 - recall: 0.6388
# Epoch 111/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3153 - accuracy: 0.0000e+00 - precision: 0.7821 - recall: 0.6299
# Epoch 112/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3139 - accuracy: 0.0000e+00 - precision: 0.7778 - recall: 0.6366: 2s - loss: 0.3127 - accuracy: 0.0000e+0
# Epoch 113/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3134 - accuracy: 0.0000e+00 - precision: 0.7788 - recall: 0.6366: 3s - loss
# Epoch 114/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3149 - accuracy: 0.0000e+00 - precision: 0.7782 - recall: 0.6342: 4s - loss: 0.3130 - accurac - ETA: 1s - loss: 0.3142 - accuracy: 0.0000e+00 - precision - ETA: 0s - loss: 0.3149 - accuracy: 0.0000e+00 - precision: 0.7779 - recall: 0.
# Epoch 115/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3126 - accuracy: 0.0000e+00 - precision: 0.7787 - recall: 0.6394
# Epoch 116/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3121 - accuracy: 0.0000e+00 - precision: 0.7822 - recall: 0.6366
# Epoch 117/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3124 - accuracy: 0.0000e+00 - precision: 0.7820 - recall: 0.6365: 3s - loss:
# Epoch 118/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3135 - accuracy: 0.0000e+00 - precision: 0.7802 - recall: 0.6326: 1s - loss: 0.3120 - accuracy: 0.0000e+00 - precision: 0.7810 - - ETA: 0s - loss: 0.3124 - accuracy: 0.0000e+00 - precision: 0.7800 -
# Epoch 119/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3130 - accuracy: 0.0000e+00 - precision: 0.7789 - recall: 0.6334: 1s - loss: 0.3127 - accuracy: 0.0000e+00 - precision: 0.7
# Epoch 120/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3103 - accuracy: 0.0000e+00 - precision: 0.7859 - recall: 0.6394: 4s - l
# Epoch 121/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3111 - accuracy: 0.0000e+00 - precision: 0.7838 - recall: 0.6352
# Epoch 122/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3121 - accuracy: 0.0000e+00 - precision: 0.7831 - recall: 0.6370
# Epoch 123/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3101 - accuracy: 0.0000e+00 - precision: 0.7840 - recall: 0.6404
# Epoch 124/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3115 - accuracy: 0.0000e+00 - precision: 0.7824 - recall: 0.6355: 2s - loss: 0.3097 - accuracy: 0.
# Epoch 125/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3112 - accuracy: 0.0000e+00 - precision: 0.7837 - recall: 0.6367: 3s - loss:
# Epoch 126/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3101 - accuracy: 0.0000e+00 - precision: 0.7838 - recall: 0.6374
# Epoch 127/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3105 - accuracy: 0.0000e+00 - precision: 0.7823 - recall: 0.6356
# Epoch 128/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3085 - accuracy: 0.0000e+00 - precision: 0.7818 - recall: 0.6393
# Epoch 129/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3107 - accuracy: 0.0000e+00 - precision: 0.7822 - recall: 0.6376
# Epoch 130/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3093 - accuracy: 0.0000e+00 - precision: 0.7848 - recall: 0.6386: - ETA: 0s - loss: 0.3090 - accuracy: 0.0000e+00 - precision: 0.7845 - recall:
# Epoch 131/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3105 - accuracy: 0.0000e+00 - precision: 0.7818 - recall: 0.6417: 1s - loss: 0.3102 - accuracy: 0.0000e+00 - precision:
# Epoch 132/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3095 - accuracy: 0.0000e+00 - precision: 0.7854 - recall: 0.6379
# Epoch 133/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3077 - accuracy: 0.0000e+00 - precision: 0.7856 - recall: 0.6397: 1s - loss: 0.3070 - accuracy: 0.0000e+00 - precision: 0.7
# Epoch 134/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3095 - accuracy: 0.0000e+00 - precision: 0.7839 - recall: 0.6387: 1s - loss: 0.3075 - accuracy: 0.0000e+00 - pre
# Epoch 135/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3093 - accuracy: 0.0000e+00 - precision: 0.7858 - recall: 0.6364
# Epoch 136/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3088 - accuracy: 0.0000e+00 - precision: 0.7871 - recall: 0.6379
# Epoch 137/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3079 - accuracy: 0.0000e+00 - precision: 0.7854 - recall: 0.6432
# Epoch 138/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3098 - accuracy: 0.0000e+00 - precision: 0.7851 - recall: 0.6336: 2s - loss: 0.3097 - accuracy: 0.0000e+00 - precision: 0.7881 - ETA: 1s - loss: 0.3099 - accuracy: 0.0000e+00 - precision: 0.
# Epoch 139/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3083 - accuracy: 0.0000e+00 - precision: 0.7846 - recall: 0.6396
# Epoch 140/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3050 - accuracy: 0.0000e+00 - precision: 0.7873 - recall: 0.6411: 6s - loss: 0. - ETA: 2s - loss: 0.3029 - accuracy: 0.0000e+00 - precision: 0.7884 - recall: 0. - ETA: 2s - loss: 0.3037 - accuracy: 0.0000e+
# Epoch 141/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3071 - accuracy: 0.0000e+00 - precision: 0.7871 - recall: 0.6391
# Epoch 142/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3064 - accuracy: 0.0000e+00 - precision: 0.7895 - recall: 0.6443
# Epoch 143/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3058 - accuracy: 0.0000e+00 - precision: 0.7844 - recall: 0.6465
# Epoch 144/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3069 - accuracy: 0.0000e+00 - precision: 0.7839 - recall: 0.6461: 0s - loss: 0.3070 - accuracy: 0.0000e+00 - precision: 0.7831 - recall: 0.
# Epoch 145/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3059 - accuracy: 0.0000e+00 - precision: 0.7833 - recall: 0.6478: 5s - loss:  - ETA: 1s - loss: 0.3062 - accuracy: 0.0000e+00 - precis
# Epoch 146/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3073 - accuracy: 0.0000e+00 - precision: 0.7839 - recall: 0.6443
# Epoch 147/150
# 416/416 [==============================] - 8s 19ms/step - loss: 0.3067 - accuracy: 0.0000e+00 - precision: 0.7841 - recall: 0.6427: 4s -
# Epoch 148/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3059 - accuracy: 0.0000e+00 - precision: 0.7866 - recall: 0.6410: 2s - loss: 0.3060 - accuracy
# Epoch 149/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3064 - accuracy: 0.0000e+00 - precision: 0.7864 - recall: 0.6445
# Epoch 150/150
# 416/416 [==============================] - 8s 20ms/step - loss: 0.3061 - accuracy: 0.0000e+00 - precision: 0.7862 - recall: 0.6435

# %%
model.save('model.h5')

# %%
ypred = model.predict_classes(x_sample)

# %%
df_test['default'] = ypred

# %%
sub = df_test[['ID','default']]

# %%
sub.to_csv('submission_2.csv',index=False)

# %%
#Creating function to trained the model
def train_test(model, x_train,y_train,x_test,y_test):
    model.fit(x_train,y_train)
    y_train_pred = model.predict(x_train)
    y_test_pred = model.predict(x_test)
    
    print('\nTraining Accuracy: ',model.score(x_train,y_train))
    print('Testing Accuracy: ',model.score(x_test,y_test))
    
    
    print('\nConfusion matrix for training set:\n')
    model_cm_train = confusion_matrix(y_train, y_train_pred)
    sns.heatmap(model_cm_train, annot=True,  fmt='.2f', xticklabels = ["0", "1"] , yticklabels = ["0", "1"] )
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()
    
    print('\nConfusion matrix for testing set:\n')
    model_cm_test = confusion_matrix(y_test, y_test_pred)
    sns.heatmap(model_cm_test, annot=True,  fmt='.2f', xticklabels = ["0", "1"] , yticklabels = ["0", "1"] )
    plt.ylabel('Actual')
    plt.xlabel('Predicted')
    plt.show()
    print('************************************************************************')
    print('\nClassification report for Training set:\n')
    print(classification_report(y_train,y_train_pred))
    
    print('\nClassification report for Testing set:\n')
    print(classification_report(y_test,y_test_pred))
    print('************************************************************************')

# %%
x_train,x_test,y_train,y_test =train_test_split(x,y,train_size=.8,random_state=1)

# %%
#Model Training 
lr = SVC()
train_test(lr,x_train, y_train, x_test, y_test)
